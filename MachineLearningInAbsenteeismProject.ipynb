# %%
import pandas as pd
import numpy as np

# %%
data_preprosseced = pd.read_csv('Final_Absenteeism_preprocessed.csv')

# %%
data_preprosseced.head()
# Out:
#    Reason1  Reason2  Reason3  Reason4  Month Value  Weekday  \
# 0        0        0        0        1            7        5
# 1        0        0        0        0            7        5
# 2        0        0        0        1            7        6
# 3        1        0        0        0            7        0
# 4        0        0        0        1            7        0
#
#    Transportation Expense  Distance to Work  Age  \
# 0                     289                36   33
# 1                     118                13   50
# 2                     179                51   38
# 3                     279                 5   39
# 4                     289                36   33
#
#    Daily Work Load Average(in Minutes)   Body Mass Index  Education  Children  \
# 0                               239.554               30          0         2
# 1                               239.554               31          0         1
# ...
